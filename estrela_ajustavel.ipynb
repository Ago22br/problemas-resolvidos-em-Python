# %% [markdown]
# ![desafio 1 osmar.png](data:image/png;base64,...)

# %%
#Resultado Com Interface

import matplotlib.pyplot as plt

print("Estrela Com tamanho Ajustavel")
print("Estrela tamanho padrão 8x8.")
escala = int(input("Escolha um tamanho: ")) #para alterar o tamanho basta mudar trocar o valor numerico

#variaveis que definem o tamanho mundanças nos valores mudam o formato
tamanho = 8 * escala
dme = 1 * escala
metade = tamanho / 2

#Coordenadas armazenadas em listas valores fixos e valores definidos atraves de operações entre as variaveis
xpontos = [0, metade - dme, metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0]
ypontos = [metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0, metade - dme, metade]

plt.plot(xpontos, ypontos)

plt.title("Desafio 01 Estrela com tamanho ajustavél")
plt.ylabel("Eixo Y")
plt.xlabel("Eixo x")

plt.grid(True)
plt.show()
# Out:
# Estrela Com tamanho Ajustavel
# Estrela tamanho padrão 8x8.
# Escolha um tamanho: 2

# %%
#Resultado: Mudar tamanho da estrela sem mudar o formato, seria posivel só mudaando a escala?

import matplotlib.pyplot as plt


escala = 1 #para alterar o tamanho basta mudar trocar o valor numerico

#variaveis que definem o tamanho mundanças nos valores mudam o formato
tamanho = 8 * escala
dme = 1 * escala
metade = tamanho / 2

#Coordenadas armazenadas em listas valores fixos e valores definidos atraves de operações entre as variaveis
xpontos = [0, metade - dme, metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0]
ypontos = [metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0, metade - dme, metade]

plt.plot(xpontos, ypontos)

plt.title("Desafio 01 Estrela com tamanho ajustavél")
plt.ylabel("Eixo Y")
plt.xlabel("Eixo x")

plt.grid(True)
plt.show()

# %%
#tentativa_03

import matplotlib.pyplot as plt

escala = 1
tamanho = 8 * escala
dme = 1 * escala
metade = tamanho / 2

xpontos = [0, metade - dme, metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0]
ypontos = [metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0, metade - dme, metade]

plt.plot(xpontos, ypontos)
plt.title("Desafio 01 Estrela com tamanho ajustavél")
plt.ylabel("Eixo Y")
plt.xlabel("Eixo x")

plt.grid(True)
plt.show()

# %%
#Tentativa_02
#erro_Formato mudando conforme a mudança do valor da variavel tamanho: tamanho variavel = formato varivel?
import matplotlib.pyplot as plt
tamanho = 8
dme = 1
dma = 5 #variavel sem uso :/
metade = tamanho/2

xpontos = [0, metade - dme, metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0]
ypontos = [metade, metade + dme, tamanho, metade + dme, metade, metade - dme, 0, metade - dme, metade]

plt.plot(xpontos, ypontos)
plt.title("Desafio 01 Estrela com tamanho ajustavél")
plt.ylabel("Eixo Y")
plt.xlabel("Eixo x")

plt.grid(True)
plt.show()
